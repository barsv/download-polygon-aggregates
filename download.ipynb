# %% [markdown]
# 1. put api key into secret.txt file next to the download.ipynb
# 2. change the list of tickers and set the timeframe (timespan and multiplier)

# %%
# Hardcoded list of tickers
TICKERS = ['AAPL', 'MSFT']  # Modify this list as needed

timespan = 'minute' # second, minute, hour, day, week, month, quarter, year
multiplier = 1

# %%
# !pip install polygon-api-client pandas python-dateutil
# Out:
# Requirement already satisfied: polygon-api-client in .\.venv\lib\site-packages (1.14.6)
# Requirement already satisfied: pandas in .\.venv\lib\site-packages (2.3.0)
# Requirement already satisfied: python-dateutil in .\.venv\lib\site-packages (2.9.0.post0)
# Requirement already satisfied: certifi<2026.0.0,>=2022.5.18 in .\.venv\lib\site-packages (from polygon-api-client) (2025.4.26)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.9 in .\.venv\lib\site-packages (from polygon-api-client) (2.4.0)
# Requirement already satisfied: websockets<15.0,>=10.3 in .\.venv\lib\site-packages (from polygon-api-client) (14.2)
# Requirement already satisfied: numpy>=1.23.2 in .\.venv\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil) (1.17.0)

# %% [markdown]
# start the download:

# %%
import os
import pandas as pd
from polygon import RESTClient
from datetime import datetime, timedelta
import logging
from dateutil import tz
import time
import sys

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        # logging.FileHandler('polygon_download.log'),
        logging.StreamHandler(sys.stdout)
    ]
)
logger = logging.getLogger()

# Read API key from secret.txt
def read_api_key(file_path='secret.txt'):
    """Read API key from secret.txt."""
    try:
        with open(file_path, 'r') as f:
            api_key = f.read().strip()
        logger.info("Successfully read API key from secret.txt")
        return api_key
    except Exception as e:
        logger.error(f"Error reading API key from {file_path}: {e}")
        return None

# Polygon API client
API_KEY = read_api_key()
if not API_KEY:
    logger.error("No API key provided. Exiting.")
    sys.exit(1)
client = RESTClient(API_KEY)

# Configuration
OUTPUT_DIR = './stock_data/'  # Directory to save CSV files
START_DATE = '2003-01-01'  # Start date for historical data
END_DATE = datetime.now().strftime('%Y-%m-%d')  # Current date
CHUNK_DAYS = 365  # Process one year at a time to manage memory
RETRY_LIMIT = 3  # Number of retries for API failures
RETRY_DELAY = 5  # Seconds to wait between retries

# Ensure output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

def convert_to_et(timestamp_ms):
    """Convert Unix timestamp (ms) in UTC to Eastern Time (ET) datetime string."""
    utc_time = datetime.utcfromtimestamp(timestamp_ms / 1000).replace(tzinfo=tz.tzutc())
    et_time = utc_time.astimezone(tz.gettz('America/New_York'))
    return et_time.strftime('%Y-%m-%d %H:%M:%S')

def fetch_aggs(ticker, start_date, end_date):
    """Fetch second-by-second aggregates for a ticker within a date range."""
    data = []
    attempt = 0
    while attempt < RETRY_LIMIT:
        try:
            logger.info(f"Fetching data for {ticker} from {start_date} to {end_date}")
            counter = 0
            for agg in client.list_aggs(
                ticker=ticker,
                multiplier=multiplier,
                timespan=timespan,
                from_=start_date,
                to=end_date,
                adjusted=True,
                sort='asc',
                limit=50000
            ):
                data.append({
                    'timestamp': convert_to_et(agg.timestamp),
                    'open': agg.open,
                    'high': agg.high,
                    'low': agg.low,
                    'close': agg.close,
                    'volume': agg.volume,
                    'vwap': agg.vwap,
                    'transactions': agg.transactions,
                    'otc': agg.otc
                })
                counter += 1
                if counter % (50 * 1000) == 0:
                    logger.info(f"Retrieved {counter} records for {ticker}")
            logger.info(f"Retrieved {len(data)} records for {ticker}")
            return data
        except Exception as e:
            attempt += 1
            logger.warning(f"Attempt {attempt}/{RETRY_LIMIT} failed for {ticker}: {e}")
            if attempt < RETRY_LIMIT:
                time.sleep(RETRY_DELAY)
            else:
                logger.error(f"Failed to fetch data for {ticker} after {RETRY_LIMIT} attempts")
                return []

def save_to_csv(ticker, data):
    """Save data to a CSV file, appending if the file exists."""
    if not data:
        logger.warning(f"No data to save for {ticker}")
        return
    df = pd.DataFrame(data)
    output_path = os.path.join(OUTPUT_DIR, f"{ticker}.csv")
    logger.info(f"Saving to {output_path}")
    try:
        if os.path.exists(output_path):
            # Append to existing file, avoid duplicating headers
            df.to_csv(output_path, mode='a', header=False, index=False)
        else:
            df.to_csv(output_path, mode='w', header=True, index=False)
        logger.info(f"Saved {len(df)} records to {output_path}")
    except Exception as e:
        logger.error(f"Error saving CSV for {ticker}: {e}")

def process_ticker(ticker, start_date, end_date):
    """Process a single ticker, fetching data in chunks."""
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    current_start = start

    while current_start < end:
        current_end = min(current_start + timedelta(days=CHUNK_DAYS), end)
        data = fetch_aggs(ticker, current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d'))
        save_to_csv(ticker, data)
        current_start = current_end + timedelta(days=1)

def main():
    if not TICKERS:
        logger.error("No tickers defined. Exiting.")
        return

    for ticker in TICKERS:
        logger.info(f"Processing ticker: {ticker}")
        process_ticker(ticker, START_DATE, END_DATE)

if __name__ == '__main__':
    main()
# Out:
# 2025-06-10 16:20:28,037 - INFO - Successfully read API key from secret.txt
# 2025-06-10 16:20:28,039 - INFO - Processing ticker: AAPL
# 2025-06-10 16:20:28,041 - INFO - Fetching data for AAPL from 2003-01-01 to 2004-01-01
# 2025-06-10 16:20:29,644 - INFO - Retrieved 32143 records for AAPL
# 2025-06-10 16:20:29,664 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16:20:29,746 - INFO - Saved 32143 records to ./stock_data/AAPL.csv
# 2025-06-10 16:20:29,748 - INFO - Fetching data for AAPL from 2004-01-02 to 2005-01-01
# 2025-06-10 16:20:31,064 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 16:20:32,523 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 16:20:32,909 - INFO - Retrieved 109827 records for AAPL
# 2025-06-10 16:20:32,985 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16:20:33,251 - INFO - Saved 109827 records to ./stock_data/AAPL.csv
# 2025-06-10 16:20:33,253 - INFO - Fetching data for AAPL from 2005-01-02 to 2006-01-02
# 2025-06-10 16:20:34,615 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 16:20:36,026 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 16:20:36,830 - INFO - Retrieved 127267 records for AAPL
# 2025-06-10 16:20:36,950 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16
- INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16:22:16,195 - INFO - Saved 203889 records to ./stock_data/AAPL.csv
# 2025-06-10 16:22:16,197 - INFO - Fetching data for AAPL from 2023-01-16 to 2024-01-16
# 2025-06-10 16:22:19,305 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 16:22:20,615 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 16:22:22,041 - INFO - Retrieved 150000 records for AAPL
# 2025-06-10 16:22:23,252 - INFO - Retrieved 188492 records for AAPL
# 2025-06-10 16:22:23,519 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16:22:24,025 - INFO - Saved 188492 records to ./stock_data/AAPL.csv
# 2025-06-10 16:22:24,028 - INFO - Fetching data for AAPL from 2024-01-17 to 2025-01-16
# 2025-06-10 16:22:25,668 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 16:22:27,027 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 16:22:28,445 - INFO - Retrieved 150000 records for AAPL
# 2025-06-10 16:22:29,562 - INFO - Retrieved 187217 records for AAPL
# 2025-06-10 16:22:29,880 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16:22:30,519 - INFO - Saved 187217 records to ./stock_data/AAPL.csv
# 2025-06-10 16:22:30,521 - INFO - Fetching data for AAPL from 2025-01-17 to 2025-06-10
# 2025-06-10 16:22:32,320 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 16:22:33,276 - INFO - Retrieved 77717 records for AAPL
# 2025-06-10 16:22:33,430 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 16:22:33,728 - INFO - Saved 77717 records to ./stock_data/AAPL.csv
# 2025-06-10 16:22:33,758 - INFO - Processing ticker: MSFT
# 2025-06-10 16:22:33,759 - INFO - Fetching data for MSFT from 2003-01-01 to 2004-01-01
# 2025-06-10 16:22:35,069 - INFO - Retrieved 39599 records for MSFT
# 2025-06-10 16:22:35,114 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:22:35,245 - INFO - Saved 39599 records to ./stock_data/MSFT.csv
# 2025-06-10 16:22:35,247 - INFO - Fetching data for MSFT from 2004-01-02 to 2005-01-01
# 2025-06-10 16:22:36,786 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:22:38,209 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:22:38,911 - INFO - Retrieved 122171 records for MSFT
# 2025-06-10 16:22:39,054 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:22:39,433 - INFO - Saved 122171 records to ./stock_data/MSFT.csv
# 2025-06-10 16:22:39,435 - INFO - Fetching data for MSFT from 2005-01-02 to 2006-01-02
# 2025-06-10 16:22:40,850 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:22:42,278 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:22:42,918 - INFO - Retrieved 119008 records for MSFT
# 2025-06-10 16:22:43,072 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:22:43,436 - INFO - Saved 119008 records to ./stock_data/MSFT.csv
# 2025-06-10 16:22:43,438 - INFO - Fetching data for MSFT from 2006-01-03 to 2007-01-03
# 2025-06-10 16:22:44,862 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:22:46,258 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:22:46,932 - INFO - Retrieved 117376 records for MSFT
# 2025-06-10 16:22:47,093 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:22:47,524 - INFO - Saved 117376 records to ./stock_data/MSFT.csv
# 2025-06-10 16:22:47,526 - INFO - Fetching data for MSFT from 2007-01-04 to 2008-01-04
# 2025-06-10 16:22:49,018 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:22:50,457 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:22:51,111 - INFO - Retrieved 117735 records for MSFT
# 2025-06-10 16:22:51,270 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:22:51,631 - INFO - Saved 117735 records to ./stock_data/MSFT.csv
# 2025-06-10 16:22:51,632 - INFO - Fetching data for MSFT from 2008-01-05 to 2009-01-04
# 2025-06-10 16:22:53,030 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:22:54,309 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:22:55,845 - INFO - Retrieved 126937 records for MSFT
# 2025-06-10 16:22:56,026 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:22:56,412 - INFO - Saved 126937 records to ./stock_data/MSFT.csv
# 2025-06-10 16:22:56,414 - INFO - Fetching data for MSFT from 2009-01-05 to 2010-01-05
# 2025-06-10 16:22:57,840 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:22:59,268 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:22:59,992 - INFO - Retrieved 122160 records for MSFT
# 2025-06-10 16:23:00,192 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:00,628 - INFO - Saved 122160 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:00,630 - INFO - Fetching data for MSFT from 2010-01-06 to 2011-01-06
# 2025-06-10 16:23:02,512 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:04,055 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:04,823 - INFO - Retrieved 124684 records for MSFT
# 2025-06-10 16:23:05,010 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:05,406 - INFO - Saved 124684 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:05,407 - INFO - Fetching data for MSFT from 2011-01-07 to 2012-01-07
# 2025-06-10 16:23:06,850 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:08,301 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:09,074 - INFO - Retrieved 122340 records for MSFT
# 2025-06-10 16:23:09,280 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:09,692 - INFO - Saved 122340 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:09,693 - INFO - Fetching data for MSFT from 2012-01-08 to 2013-01-07
# 2025-06-10 16:23:11,144 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:12,570 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:13,184 - INFO - Retrieved 117272 records for MSFT
# 2025-06-10 16:23:13,377 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:13,818 - INFO - Saved 117272 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:13,821 - INFO - Fetching data for MSFT from 2013-01-08 to 2014-01-08
# 2025-06-10 16:23:15,334 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:16,930 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:17,584 - INFO - Retrieved 117346 records for MSFT
# 2025-06-10 16:23:17,779 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:18,158 - INFO - Saved 117346 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:18,160 - INFO - Fetching data for MSFT from 2014-01-09 to 2015-01-09
# 2025-06-10 16:23:19,720 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:21,011 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:21,597 - INFO - Retrieved 113322 records for MSFT
# 2025-06-10 16:23:21,804 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:22,150 - INFO - Saved 113322 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:22,151 - INFO - Fetching data for MSFT from 2015-01-10 to 2016-01-10
# 2025-06-10 16:23:23,500 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:24,680 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:25,240 - INFO - Retrieved 115893 records for MSFT
# 2025-06-10 16:23:25,399 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:25,701 - INFO - Saved 115893 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:25,702 - INFO - Fetching data for MSFT from 2016-01-11 to 2017-01-10
# 2025-06-10 16:23:26,893 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:28,101 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:28,648 - INFO - Retrieved 114112 records for MSFT
# 2025-06-10 16:23:28,815 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:29,137 - INFO - Saved 114112 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:29,138 - INFO - Fetching data for MSFT from 2017-01-11 to 2018-01-11
# 2025-06-10 16:23:30,337 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:31,538 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:32,062 - INFO - Retrieved 113752 records for MSFT
# 2025-06-10 16:23:32,223 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:32,512 - INFO - Saved 113752 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:32,515 - INFO - Fetching data for MSFT from 2018-01-12 to 2019-01-12
# 2025-06-10 16:23:33,689 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:34,942 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:35,812 - INFO - Retrieved 134043 records for MSFT
# 2025-06-10 16:23:35,995 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:36,359 - INFO - Saved 134043 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:36,361 - INFO - Fetching data for MSFT from 2019-01-13 to 2020-01-13
# 2025-06-10 16:23:37,650 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:38,830 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:39,778 - INFO - Retrieved 137369 records for MSFT
# 2025-06-10 16:23:39,960 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:40,344 - INFO - Saved 137369 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:40,346 - INFO - Fetching data for MSFT from 2020-01-14 to 2021-01-13
# 2025-06-10 16:23:41,805 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:43,258 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:44,489 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 16:23:45,171 - INFO - Retrieved 173408 records for MSFT
# 2025-06-10 16:23:45,397 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:45,884 - INFO - Saved 173408 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:45,887 - INFO - Fetching data for MSFT from 2021-01-14 to 2022-01-14
# 2025-06-10 16:23:47,209 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:48,454 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:49,691 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 16:23:49,904 - INFO - Retrieved 151967 records for MSFT
# 2025-06-10 16:23:50,108 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:50,522 - INFO - Saved 151967 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:50,524 - INFO - Fetching data for MSFT from 2022-01-15 to 2023-01-15
# 2025-06-10 16:23:52,122 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:53,398 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:54,709 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 16:23:55,050 - INFO - Retrieved 156204 records for MSFT
# 2025-06-10 16:23:55,312 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:23:55,775 - INFO - Saved 156204 records to ./stock_data/MSFT.csv
# 2025-06-10 16:23:55,777 - INFO - Fetching data for MSFT from 2023-01-16 to 2024-01-16
# 2025-06-10 16:23:57,207 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:23:58,531 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:23:59,795 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 16:24:00,287 - INFO - Retrieved 160656 records for MSFT
# 2025-06-10 16:24:00,520 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:24:00,969 - INFO - Saved 160656 records to ./stock_data/MSFT.csv
# 2025-06-10 16:24:00,972 - INFO - Fetching data for MSFT from 2024-01-17 to 2025-01-16
# 2025-06-10 16:24:02,409 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:24:03,686 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 16:24:04,978 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 16:24:05,231 - INFO - Retrieved 153618 records for MSFT
# 2025-06-10 16:24:05,447 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:24:05,870 - INFO - Saved 153618 records to ./stock_data/MSFT.csv
# 2025-06-10 16:24:05,873 - INFO - Fetching data for MSFT from 2025-01-17 to 2025-06-10
# 2025-06-10 16:24:07,325 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 16:24:07,883 - INFO - Retrieved 61960 records for MSFT
# 2025-06-10 16:24:08,026 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 16:24:08,228 - INFO - Saved 61960 records to ./stock_data/MSFT.csv
