# %% [markdown]
# 1. put api key into secret.txt file next to the download.ipynb
# 2. change the list of tickers and set the timeframe (timespan and multiplier)

# %%
# Hardcoded list of tickers
TICKERS = ['AAPL', 'MSFT']  # Modify this list as needed

timespan = 'minute' # second, minute, hour, day, week, month, quarter, year
multiplier = 1

# %%
# !pip install polygon-api-client pandas python-dateutil
# Out:
# Collecting polygon-api-client
#   Downloading polygon_api_client-1.14.6-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 KB 641.5 kB/s eta 0:00:0031m1.3 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 45.2 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.10/site-packages (2.9.0.post0)
# Collecting websockets<15.0,>=10.3
#   Downloading websockets-14.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.3/169.3 KB 8.6 MB/s eta 0:00:00
# Collecting urllib3<3.0.0,>=1.26.9
#   Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Collecting certifi<2026.0.0,>=2022.5.18
#   Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 28.2 MB/s eta 0:00:00
# Collecting numpy>=1.22.4
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 48.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil) (1.17.0)
# Installing collected packages: pytz, websockets, urllib3, tzdata, numpy, certifi, polygon-api-client, pandas
# Successfully installed certifi-2025.4.26 numpy-2.2.6 pandas-2.3.0 polygon-api-client-1.14.6 pytz-2025.2 tzdata-2025.2 urllib3-2.4.0 websockets-14.2

# %% [markdown]
# start the download:

# %%
import os
import pandas as pd
from polygon import RESTClient
from datetime import datetime, timedelta
import logging
from dateutil import tz
import time
import sys

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        # logging.FileHandler('polygon_download.log'),
        logging.StreamHandler(sys.stdout)
    ]
)
logger = logging.getLogger()

# Read API key from secret.txt
def read_api_key(file_path='secret.txt'):
    """Read API key from secret.txt."""
    try:
        with open(file_path, 'r') as f:
            api_key = f.read().strip()
        logger.info("Successfully read API key from secret.txt")
        return api_key
    except Exception as e:
        logger.error(f"Error reading API key from {file_path}: {e}")
        return None

# Polygon API client
API_KEY = read_api_key()
if not API_KEY:
    logger.error("No API key provided. Exiting.")
    sys.exit(1)
client = RESTClient(API_KEY)

# Configuration
OUTPUT_DIR = './stock_data/'  # Directory to save CSV files
START_DATE = '2003-01-01'  # Start date for historical data
END_DATE = datetime.now().strftime('%Y-%m-%d')  # Current date
CHUNK_DAYS = 365  # Process one year at a time to manage memory
RETRY_LIMIT = 3  # Number of retries for API failures
RETRY_DELAY = 5  # Seconds to wait between retries

# Ensure output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

def convert_to_et(timestamp_ms):
    """Convert Unix timestamp (ms) in UTC to Eastern Time (ET) datetime string."""
    utc_time = datetime.utcfromtimestamp(timestamp_ms / 1000).replace(tzinfo=tz.tzutc())
    et_time = utc_time.astimezone(tz.gettz('America/New_York'))
    return et_time.strftime('%Y-%m-%d %H:%M:%S')

def fetch_aggs(ticker, start_date, end_date):
    """Fetch second-by-second aggregates for a ticker within a date range."""
    data = []
    attempt = 0
    while attempt < RETRY_LIMIT:
        try:
            logger.info(f"Fetching data for {ticker} from {start_date} to {end_date}")
            counter = 0
            for agg in client.list_aggs(
                ticker=ticker,
                multiplier=multiplier,
                timespan=timespan,
                from_=start_date,
                to=end_date,
                adjusted=True,
                sort='asc',
                limit=50000
            ):
                data.append({
                    'timestamp': convert_to_et(agg.timestamp),
                    'open': agg.open,
                    'high': agg.high,
                    'low': agg.low,
                    'close': agg.close,
                    'volume': agg.volume,
                    'vwap': agg.vwap,
                    'transactions': agg.transactions,
                    'otc': agg.otc
                })
                counter += 1
                if counter % (50 * 1000) == 0:
                    logger.info(f"Retrieved {counter} records for {ticker}")
            logger.info(f"Retrieved {len(data)} records for {ticker}")
            return data
        except Exception as e:
            attempt += 1
            logger.warning(f"Attempt {attempt}/{RETRY_LIMIT} failed for {ticker}: {e}")
            if attempt < RETRY_LIMIT:
                time.sleep(RETRY_DELAY)
            else:
                logger.error(f"Failed to fetch data for {ticker} after {RETRY_LIMIT} attempts")
                return []

def save_to_csv(ticker, data):
    """Save data to a CSV file, appending if the file exists."""
    if not data:
        logger.warning(f"No data to save for {ticker}")
        return
    df = pd.DataFrame(data)
    output_path = os.path.join(OUTPUT_DIR, f"{ticker}.csv")
    logger.info(f"Saving to {output_path}")
    try:
        if os.path.exists(output_path):
            # Append to existing file, avoid duplicating headers
            df.to_csv(output_path, mode='a', header=False, index=False)
        else:
            df.to_csv(output_path, mode='w', header=True, index=False)
        logger.info(f"Saved {len(df)} records to {output_path}")
    except Exception as e:
        logger.error(f"Error saving CSV for {ticker}: {e}")

def process_ticker(ticker, start_date, end_date):
    """Process a single ticker, fetching data in chunks."""
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    current_start = start

    while current_start < end:
        current_end = min(current_start + timedelta(days=CHUNK_DAYS), end)
        data = fetch_aggs(ticker, current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d'))
        save_to_csv(ticker, data)
        current_start = current_end + timedelta(days=1)

def main():
    if not TICKERS:
        logger.error("No tickers defined. Exiting.")
        return

    for ticker in TICKERS:
        logger.info(f"Processing ticker: {ticker}")
        process_ticker(ticker, START_DATE, END_DATE)

if __name__ == '__main__':
    main()
# Out:
# 2025-06-10 19:22:37,249 - INFO - Successfully read API key from secret.txt
# 2025-06-10 19:22:37,251 - INFO - Processing ticker: AAPL
# 2025-06-10 19:22:37,251 - INFO - Fetching data for AAPL from 2003-01-01 to 2004-01-01
# 2025-06-10 19:22:39,381 - INFO - Retrieved 32143 records for AAPL
# 2025-06-10 19:22:39,418 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 19:22:39,554 - INFO - Saved 32143 records to ./stock_data/AAPL.csv
# 2025-06-10 19:22:39,555 - INFO - Fetching data for AAPL from 2004-01-02 to 2005-01-01
# 2025-06-10 19:22:41,844 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 19:22:43,840 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 19:22:44,466 - INFO - Retrieved 109827 records for AAPL
# 2025-06-10 19:22:44,640 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 19:22:45,134 - INFO - Saved 109827 records to ./stock_data/AAPL.csv
# 2025-06-10 19:22:45,137 - INFO - Fetching data for AAPL from 2005-01-02 to 2006-01-02
# 2025-06-10 19:22:47,782 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 19:22:50,357 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 19:22:51,969 - INFO - Retrieved 127267 records for AAPL
# 2025-06-10 19:22:52,186 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 19
- INFO - Retrieved 50000 records for AAPL
# 2025-06-10 19:25:18,590 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 19:25:20,573 - INFO - Retrieved 150000 records for AAPL
# 2025-06-10 19:25:22,135 - INFO - Retrieved 188492 records for AAPL
# 2025-06-10 19:25:22,451 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 19:25:23,062 - INFO - Saved 188492 records to ./stock_data/AAPL.csv
# 2025-06-10 19:25:23,067 - INFO - Fetching data for AAPL from 2024-01-17 to 2025-01-16
# 2025-06-10 19:25:25,208 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 19:25:27,312 - INFO - Retrieved 100000 records for AAPL
# 2025-06-10 19:25:29,629 - INFO - Retrieved 150000 records for AAPL
# 2025-06-10 19:25:31,487 - INFO - Retrieved 187217 records for AAPL
# 2025-06-10 19:25:31,990 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 19:25:32,950 - INFO - Saved 187217 records to ./stock_data/AAPL.csv
# 2025-06-10 19:25:32,955 - INFO - Fetching data for AAPL from 2025-01-17 to 2025-06-10
# 2025-06-10 19:25:35,257 - INFO - Retrieved 50000 records for AAPL
# 2025-06-10 19:25:36,505 - INFO - Retrieved 77900 records for AAPL
# 2025-06-10 19:25:36,739 - INFO - Saving to ./stock_data/AAPL.csv
# 2025-06-10 19:25:37,102 - INFO - Saved 77900 records to ./stock_data/AAPL.csv
# 2025-06-10 19:25:37,146 - INFO - Processing ticker: MSFT
# 2025-06-10 19:25:37,148 - INFO - Fetching data for MSFT from 2003-01-01 to 2004-01-01
# 2025-06-10 19:25:38,701 - INFO - Retrieved 39599 records for MSFT
# 2025-06-10 19:25:38,759 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:25:38,940 - INFO - Saved 39599 records to ./stock_data/MSFT.csv
# 2025-06-10 19:25:38,942 - INFO - Fetching data for MSFT from 2004-01-02 to 2005-01-01
# 2025-06-10 19:25:40,631 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:25:42,470 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:25:43,433 - INFO - Retrieved 122171 records for MSFT
# 2025-06-10 19:25:43,706 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:25:44,258 - INFO - Saved 122171 records to ./stock_data/MSFT.csv
# 2025-06-10 19:25:44,263 - INFO - Fetching data for MSFT from 2005-01-02 to 2006-01-02
# 2025-06-10 19:25:46,309 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:25:48,217 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:25:49,244 - INFO - Retrieved 119008 records for MSFT
# 2025-06-10 19:25:49,488 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:25:50,053 - INFO - Saved 119008 records to ./stock_data/MSFT.csv
# 2025-06-10 19:25:50,055 - INFO - Fetching data for MSFT from 2006-01-03 to 2007-01-03
# 2025-06-10 19:25:51,795 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:25:53,267 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:25:53,904 - INFO - Retrieved 117376 records for MSFT
# 2025-06-10 19:25:54,062 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:25:54,479 - INFO - Saved 117376 records to ./stock_data/MSFT.csv
# 2025-06-10 19:25:54,481 - INFO - Fetching data for MSFT from 2007-01-04 to 2008-01-04
# 2025-06-10 19:25:55,991 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:25:57,798 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:25:58,926 - INFO - Retrieved 117735 records for MSFT
# 2025-06-10 19:25:59,305 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:00,148 - INFO - Saved 117735 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:00,151 - INFO - Fetching data for MSFT from 2008-01-05 to 2009-01-04
# 2025-06-10 19:26:02,402 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:04,645 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:06,522 - INFO - Retrieved 126937 records for MSFT
# 2025-06-10 19:26:06,823 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:07,489 - INFO - Saved 126937 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:07,492 - INFO - Fetching data for MSFT from 2009-01-05 to 2010-01-05
# 2025-06-10 19:26:09,563 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:11,315 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:12,320 - INFO - Retrieved 122160 records for MSFT
# 2025-06-10 19:26:12,531 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:13,007 - INFO - Saved 122160 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:13,010 - INFO - Fetching data for MSFT from 2010-01-06 to 2011-01-06
# 2025-06-10 19:26:14,949 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:16,752 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:18,082 - INFO - Retrieved 124684 records for MSFT
# 2025-06-10 19:26:18,270 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:18,692 - INFO - Saved 124684 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:18,694 - INFO - Fetching data for MSFT from 2011-01-07 to 2012-01-07
# 2025-06-10 19:26:20,206 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:21,905 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:22,944 - INFO - Retrieved 122340 records for MSFT
# 2025-06-10 19:26:23,238 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:23,709 - INFO - Saved 122340 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:23,715 - INFO - Fetching data for MSFT from 2012-01-08 to 2013-01-07
# 2025-06-10 19:26:25,677 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:27,790 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:28,732 - INFO - Retrieved 117272 records for MSFT
# 2025-06-10 19:26:29,070 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:29,503 - INFO - Saved 117272 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:29,505 - INFO - Fetching data for MSFT from 2013-01-08 to 2014-01-08
# 2025-06-10 19:26:31,377 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:33,548 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:34,533 - INFO - Retrieved 117346 records for MSFT
# 2025-06-10 19:26:34,755 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:35,144 - INFO - Saved 117346 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:35,146 - INFO - Fetching data for MSFT from 2014-01-09 to 2015-01-09
# 2025-06-10 19:26:37,048 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:38,683 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:39,275 - INFO - Retrieved 113322 records for MSFT
# 2025-06-10 19:26:39,455 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:39,818 - INFO - Saved 113322 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:39,819 - INFO - Fetching data for MSFT from 2015-01-10 to 2016-01-10
# 2025-06-10 19:26:41,500 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:43,200 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:44,034 - INFO - Retrieved 115893 records for MSFT
# 2025-06-10 19:26:44,235 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:44,671 - INFO - Saved 115893 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:44,672 - INFO - Fetching data for MSFT from 2016-01-11 to 2017-01-10
# 2025-06-10 19:26:46,411 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:48,061 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:48,928 - INFO - Retrieved 114112 records for MSFT
# 2025-06-10 19:26:49,138 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:49,540 - INFO - Saved 114112 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:49,542 - INFO - Fetching data for MSFT from 2017-01-11 to 2018-01-11
# 2025-06-10 19:26:51,307 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:53,089 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:53,745 - INFO - Retrieved 113752 records for MSFT
# 2025-06-10 19:26:53,967 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:26:54,514 - INFO - Saved 113752 records to ./stock_data/MSFT.csv
# 2025-06-10 19:26:54,517 - INFO - Fetching data for MSFT from 2018-01-12 to 2019-01-12
# 2025-06-10 19:26:56,429 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:26:58,072 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:26:59,513 - INFO - Retrieved 134043 records for MSFT
# 2025-06-10 19:26:59,839 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:00,547 - INFO - Saved 134043 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:00,549 - INFO - Fetching data for MSFT from 2019-01-13 to 2020-01-13
# 2025-06-10 19:27:02,739 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:04,772 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:27:06,234 - INFO - Retrieved 137369 records for MSFT
# 2025-06-10 19:27:06,560 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:07,186 - INFO - Saved 137369 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:07,188 - INFO - Fetching data for MSFT from 2020-01-14 to 2021-01-13
# 2025-06-10 19:27:09,412 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:11,071 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:27:12,613 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 19:27:13,667 - INFO - Retrieved 173408 records for MSFT
# 2025-06-10 19:27:13,926 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:14,471 - INFO - Saved 173408 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:14,474 - INFO - Fetching data for MSFT from 2021-01-14 to 2022-01-14
# 2025-06-10 19:27:16,280 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:17,842 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:27:19,994 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 19:27:20,233 - INFO - Retrieved 151967 records for MSFT
# 2025-06-10 19:27:20,474 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:20,982 - INFO - Saved 151967 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:20,984 - INFO - Fetching data for MSFT from 2022-01-15 to 2023-01-15
# 2025-06-10 19:27:23,053 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:24,548 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:27:26,063 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 19:27:26,430 - INFO - Retrieved 156204 records for MSFT
# 2025-06-10 19:27:26,711 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:27,390 - INFO - Saved 156204 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:27,392 - INFO - Fetching data for MSFT from 2023-01-16 to 2024-01-16
# 2025-06-10 19:27:29,515 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:31,587 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:27:33,399 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 19:27:33,992 - INFO - Retrieved 160656 records for MSFT
# 2025-06-10 19:27:34,262 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:34,811 - INFO - Saved 160656 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:34,815 - INFO - Fetching data for MSFT from 2024-01-17 to 2025-01-16
# 2025-06-10 19:27:36,673 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:38,321 - INFO - Retrieved 100000 records for MSFT
# 2025-06-10 19:27:39,985 - INFO - Retrieved 150000 records for MSFT
# 2025-06-10 19:27:40,297 - INFO - Retrieved 153618 records for MSFT
# 2025-06-10 19:27:40,601 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:41,390 - INFO - Saved 153618 records to ./stock_data/MSFT.csv
# 2025-06-10 19:27:41,393 - INFO - Fetching data for MSFT from 2025-01-17 to 2025-06-10
# 2025-06-10 19:27:43,413 - INFO - Retrieved 50000 records for MSFT
# 2025-06-10 19:27:44,059 - INFO - Retrieved 62142 records for MSFT
# 2025-06-10 19:27:44,187 - INFO - Saving to ./stock_data/MSFT.csv
# 2025-06-10 19:27:44,416 - INFO - Saved 62142 records to ./stock_data/MSFT.csv
